# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector
# Out:
# ...
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247961 sha256=17ddb81eae0e0d3a6729b09792af15c19ec12562526a3c83ff773fd735378414
#   Stored in directory: c:\users\salba\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql-connector
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
from mysql.connector import errorcode
import pandas as pd
import numpy as np
import pandas.io.sql as psql

# %% [markdown]
# Create connexion with our DB.

# %%
cnx = mysql.connector.connect(user='root', password='P@t020231202', database='birdsdb')
cursor = cnx.cursor()

# %% [markdown]
# Load all relations into pandas dataframes so we can work with them.

# %%
query = "SELECT * from especie"

sql_query = pd.read_sql_query(query,cnx)
avistamiento = pd.DataFrame(sql_query, columns = ['nombre', 'orden', 'familia','genus','nombre_comun','invasivo','conservacion','taxon_ID','reproductive_condition',
                                                  'behavior', 'occurrence_satatus', 'year', 'month', 'day','time', 'contient','country', 
                                                  'state_province','locality','place'])

avistamiento
# Out:
# C:\Users\salba\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     avistamiento_id                     especie   basis_of_record  \
# 0                 0                 Fulica atra  HumanObservation
# 1                 1                 Buteo buteo  HumanObservation
# 2               100          Anas platyrhynchos  HumanObservation
# 3               103               Turdus merula  HumanObservation
# 4               104  Chroicocephalus ridibundus  HumanObservation
# ..              ...                         ...               ...
# 121              94          Erithacus rubecula  HumanObservation
# 122              95           Passer domesticus  HumanObservation
# 123              96          Anas platyrhynchos  HumanObservation
# ...

# %%
query = "SELECT * from avistamiento"

sql_query = pd.read_sql_query(query,cnx)
avistamiento = pd.DataFrame(sql_query, columns = ['avistamiento_id', 'especie', 'basis_of_record','institution_code','organism_quantity','latitude','longitude','sex','reproductive_condition',
                                                  'behavior', 'occurrence_satatus', 'year', 'month', 'day','time', 'contient','country', 
                                                  'state_province','locality','place'])

# %%
cursor.close()
cnx.close()
