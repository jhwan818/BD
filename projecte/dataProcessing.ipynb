# %%
import pandas as pd
import numpy as np

# %%
dades1 = pd.read_csv("dades/records-2023-04-25.csv")
dades1.head()
# Out:
#    Species       Species Name Scientific Name Authorship Taxon Rank   Kingdom  \
# 0  9687165     Motacilla alba             Linnaeus, 1758    species  Animalia
# 1  5231190  Passer domesticus           (Linnaeus, 1758)    species  Animalia
# 2  5229490          Pica pica           (Linnaeus, 1758)    species  Animalia
# 3  2490719      Turdus merula             Linnaeus, 1758    species  Animalia
# 4  2495455   Columba palumbus             Linnaeus, 1758    species  Animalia
#
#      Phylum Class          Order        Family      Genus     Vernacular Name  \
# 0  Chordata  Aves  Passeriformes  Motacillidae  Motacilla       White Wagtail
# 1  Chordata  Aves  Passeriformes    Passeridae     Passer       House Sparrow
# 2  Chordata  Aves  Passeriformes      Corvidae       Pica     Eurasian Magpie
# 3  Chordata  Aves  Passeriformes      Turdidae     Turdus  Eurasian Blackbird
# 4  Chordata  Aves  Columbiformes    Columbidae    Columba  Common Wood-Pigeon
#
#   Conservation Invasive
# 0          NaN      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN

# %%
inv = dades1["Conservation"].dropna()

# %%
inv
# Out:
# 8      Listado de Especies Silvestres en Régimen de P...
# 13     Listado de Especies Silvestres en Régimen de P...
# 17     Listado de Especies Silvestres en Régimen de P...
# 21     Listado de Especies Silvestres en Régimen de P...
# 29     Listado de Especies Silvestres en Régimen de P...
#                              ...
# 225    Listado de Especies Silvestres en Régimen de P...
# 229    Listado de Especies Silvestres en Régimen de P...
# 231    Listado de Especies Silvestres en Régimen de P...
# 236    Listado de Especies Silvestres en Régimen de P...
# 242    Listado de Especies Silvestres en Régimen de P...
# Name: Conservation, Length: 65, dtype: object

# %%
dades2 = pd.read_csv("dades/records-2023-03-14/citation.csv")
dades2.head()
# Out:
#      UID                                               Name  \
# 0  co255           Datos recogidos en el proyecto Biobserva
# 1    dp2                                        GBIF ES IPT
# 2  dr743  Field observations of birds from Agbar facilit...
# 3  in109                                              AGBAR
#
#                    DOI                                           Citation  \
# 0                  NaN  Registros proporcionados por Datos recogidos e...
# 1                  NaN  Registros proporcionados por GBIF ES IPT, acce...
# 2  doi:10.15470/uykaay  Rovira C (2022): Field observations of birds f...
# 3                  NaN  Registros proporcionados por AGBAR, accedidos ...
#
#                                               Rights  \
# 0                                                NaN
# 1                                                NaN
# 2  Creative Commons Zero (CC0) To the extent poss...
# 3                                                NaN
#
#                                     More Information  Data generalisations  \
# 0  Más información: https://colecciones.gbif.es/p...                   NaN
# 1  Más información: https://colecciones.gbif.es/p...                   NaN
# 2  Más información: https://colecciones.gbif.es/p...                   NaN
# 3  Más información: https://colecciones.gbif.es/p...                   NaN
#
#    Information withheld  Download limit  Number of Records in Download
# 0                   NaN             NaN                         101917
# 1                   NaN             NaN                         101917
# 2                   NaN             NaN                         101917
# 3                   NaN             NaN                         101917

# %%
for i in dades2.columns:
    print(i)
# Out:
# UID
# Name
# DOI
# Citation
# Rights
# More Information
# Data generalisations
# Information withheld
# Download limit
# Number of Records in Download

# %%
dades3 = pd.read_csv("dades/records-2023-03-14/headings.csv")
dades3.head()
# Out:
#             Column name    Requested field              DwC Name  \
# 0     data_resource_uid  data_resource_uid                   NaN
# 1      dcterms:language           language      dcterms:language
# 2       dcterms:license            license       dcterms:license
# 3  dcterms:rightsHolder       rightsholder  dcterms:rightsHolder
# 4         access_rights      access_rights  dcterms:accessRights
#
#           Field name Field description Download field name  \
# 0  data_resource_uid           Dataset   data_resource_uid
# 1           language               NaN            language
# 2            license           License             license
# 3       rightsholder               NaN        rightsholder
# 4      access_rights               NaN       access_rights
#
#   Download field description                    More information
# 0           Data Resource ID  The Atlas ID for the data resource
# 1                        NaN              Language of the record
# 2                    Licence   The license applying to a record.
# 3                        NaN                                 NaN
# 4                        NaN                                 NaN

# %%
for i in dades3.columns:
    print(i)
# Out:
# Column name
# Requested field
# DwC Name
# Field name
# Field description
# Download field name
# Download field description
# More information

# %%
data4 = pd.read_csv("dades/records-2023-03-14/records-2023-03-14.csv")
data4.head()
# Out:
#   data_resource_uid dcterms:language dcterms:license  dcterms:rightsHolder  \
# 0             dr743               en             CC0                   NaN
# 1             dr743               en             CC0                   NaN
# 2             dr743               en             CC0                   NaN
# 3             dr743               en             CC0                   NaN
# 4             dr743               en             CC0                   NaN
#
#    access_rights  dcterms:bibliographicCitation  institutionID  collectionID  \
# 0            NaN                            NaN            NaN           NaN
# 1            NaN                            NaN            NaN           NaN
# 2            NaN                            NaN            NaN           NaN
# 3            NaN                            NaN            NaN           NaN
# 4            NaN                            NaN            NaN           NaN
#
#              datasetID institutionCode  ... taxonomicStatus  \
# 0  doi:10.15470/uykaay           AGBAR  ...             NaN
# 1  doi:10.15470/uykaay           AGBAR  ...             NaN
# 2  doi:10.15470/uykaay            SUEZ  ...             NaN
# 3  doi:10.15470/uykaay           AGBAR  ...             NaN
# 4  doi:10.15470/uykaay            SUEZ  ...             NaN
#
#   nomenclaturalStatus  taxonRemarks                     species  \
# 0                 NaN           NaN                 Fulica atra
# 1                 NaN           NaN                 Buteo buteo
# 2                 NaN           NaN  Chroicocephalus ridibundus
# 3                 NaN           NaN       Streptopelia decaocto
# 4                 NaN           NaN           Motacilla cinerea
#
#    verbatimIdentificationQualifier         provenance  \
# 0                              NaN  Published dataset
# 1                              NaN  Published dataset
# 2                              NaN  Published dataset
# 3                              NaN  Published dataset
# 4                              NaN  Published dataset
#
#                                recordID  dcterms:accessRights  \
# 0  fffbadf9-b2e2-4eb5-9693-66cc9f1ae275                   NaN
# 1  fff64d93-c37e-4a41-82fa-741ee0890278                   NaN
# 2  fff08d30-3555-43f8-a43b-d4c1f9fe47dd                   NaN
# 3  ffe1f1c1-d7d3-4ba6-8e99-5d9377a6c0d7                   NaN
# 4  ffe18f1c-7d64-41df-9dfe-b3c0630a34fd                   NaN
#
#    verbatimContinent  verbatimBasisOfRecord
# 0             Europe       HumanObservation
# 1             Europe       HumanObservation
# 2             Europe       HumanObservation
# 3             Europe       HumanObservation
# 4             Europe       HumanObservation
#
# [5 rows x 132 columns]

# %%
for i in data4.columns:
    print(i)
# Out:
# data_resource_uid
# dcterms:language
# dcterms:license
# dcterms:rightsHolder
# access_rights
# dcterms:bibliographicCitation
# institutionID
# collectionID
# datasetID
# institutionCode
# collectionCode
# datasetName
# ownerInstitutionCode
# basisOfRecord
# dynamicProperties
# occurrenceID
# catalogNumber
# recordNumber
# recordedBy
# individualCount
# organism_quantity
# organism_quantity_type
# sex
# reproductiveCondition
# behavior
# establishmentMeans
# occurrenceStatus
# preparations
# disposition
# associatedMedia
# associatedSequences
# associatedTaxa
# otherCatalogNumbers
# occurrenceRemarks
# previousIdentifications
# eventID
# fieldNumber
# eventDate
# eventTime
# startDayOfYear
# endDayOfYear
# year
# month
# day
# verbatimEventDate
# habitat
# samplingEffort
# fieldNotes
# eventRemarks
# locationID
# higherGeographyID
# higherGeography
# waterBody
# islandGroup
# island
# country
# countryCode
# stateProvince
# county
# municipality
# locality
# verbatimLocality
# minimumElevationInMeters
# maximumElevationInMeters
# verbatimElevation
# minimumDepthInMeters
# maximumDepthInMeters
# minimum_distance_above_surface_in_meters
# maximum_distance_above_surface_in_meters
# locationAccordingTo
# locationRemarks
# decimalLatitude
# decimalLongitude
# geodeticDatum
# coordinateUncertaintyInMeters
# pointRadiusSpatialFit
# verbatimCoordinates
# verbatimLatitude
# verbatimLatitude.1
# verbatimLongitude
# verbatimLongitude.1
# verbatimCoordinateSystem
# verbatimCoordinateSystem.1
# verbatimSRS
# footprintWKT
# georeferencedBy
# georeferencedDate
# georeferenceProtocol
# georeferenceSources
# georeference_verification_status
# georeferenceRemarks
# identificationID
# identificationQualifier
# typeStatus
# identifiedBy
# dateIdentified
# identificationVerificationStatus
# identificationRemarks
# taxonID
# scientificNameID
# taxonConceptID
# scientificName
# scientificName.1
# acceptedNameUsage
# parentNameUsage
# originalNameUsage
# namePublishedIn
# name_published_in_year
# higherClassification
# kingdom
# phylum
# class
# order
# family
# genus
# subgenus
# specificEpithet
# infraspecificEpithet
# taxonRank
# verbatimTaxonRank
# scientificNameAuthorship
# vernacularName
# taxonomicStatus
# nomenclaturalStatus
# taxonRemarks
# species
# verbatimIdentificationQualifier
# provenance
# recordID
# dcterms:accessRights
# verbatimContinent
# verbatimBasisOfRecord
