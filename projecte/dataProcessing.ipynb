# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("records-2023-03-07/records-2023-03-07.csv")
data.head()
# Out:
#   data_resource_uid dcterms:language dcterms:license  dcterms:rightsHolder  \
# 0             dr743               en             CC0                   NaN
# 1             dr743               en             CC0                   NaN
# 2             dr743               en             CC0                   NaN
# 3             dr743               en             CC0                   NaN
# 4             dr743               en             CC0                   NaN
#
#    access_rights  dcterms:bibliographicCitation  institutionID  collectionID  \
# 0            NaN                            NaN            NaN           NaN
# 1            NaN                            NaN            NaN           NaN
# 2            NaN                            NaN            NaN           NaN
# 3            NaN                            NaN            NaN           NaN
# 4            NaN                            NaN            NaN           NaN
#
# ...

# %%
data2 = pd.read_csv("dades/records-2023-03-14.csv")
data2.head()
# Out:
#    Species       Species Name Scientific Name Authorship Taxon Rank   Kingdom  \
# 0  9687165     Motacilla alba             Linnaeus, 1758    species  Animalia
# 1  5231190  Passer domesticus           (Linnaeus, 1758)    species  Animalia
# 2  5229490          Pica pica           (Linnaeus, 1758)    species  Animalia
# 3  2490719      Turdus merula             Linnaeus, 1758    species  Animalia
# 4  2495455   Columba palumbus             Linnaeus, 1758    species  Animalia
#
#      Phylum Class          Order        Family      Genus Vernacular Name  \
# 0  Chordata  Aves  Passeriformes  Motacillidae  Motacilla      Bachstelze
# 1  Chordata  Aves  Passeriformes    Passeridae     Passer    Haussperling
# 2  Chordata  Aves  Passeriformes      Corvidae       Pica   Common Magpie
# 3  Chordata  Aves  Passeriformes      Turdidae     Turdus           Amsel
# 4  Chordata  Aves  Columbiformes    Columbidae    Columba     Dielkoduvvá
#
#   Conservation Invasive
# 0          NaN      NaN
# ...

# %%
data3 = pd.read_csv("dades/records-2023-03-14/records-2023-03-14.csv")

# %%
data3.head()
# Out:
#   data_resource_uid dcterms:language dcterms:license  dcterms:rightsHolder  \
# 0             dr743               en             CC0                   NaN
# 1             dr743               en             CC0                   NaN
# 2             dr743               en             CC0                   NaN
# 3             dr743               en             CC0                   NaN
# 4             dr743               en             CC0                   NaN
#
#    access_rights  dcterms:bibliographicCitation  institutionID  collectionID  \
# 0            NaN                            NaN            NaN           NaN
# 1            NaN                            NaN            NaN           NaN
# 2            NaN                            NaN            NaN           NaN
# 3            NaN                            NaN            NaN           NaN
# 4            NaN                            NaN            NaN           NaN
#
# ...

# %%
np.shape(data)
# Out:
# (23182, 132)

# %%
list(data3.columns)
# Out:
# ['data_resource_uid',
#  'dcterms:language',
#  'dcterms:license',
#  'dcterms:rightsHolder',
#  'access_rights',
#  'dcterms:bibliographicCitation',
#  'institutionID',
#  'collectionID',
#  'datasetID',
#  'institutionCode',
#  'collectionCode',
#  'datasetName',
#  'ownerInstitutionCode',
#  'basisOfRecord',
#  'dynamicProperties',
#  'occurrenceID',
#  'catalogNumber',
#  'recordNumber',
#  'recordedBy',
#  'individualCount',
#  'organism_quantity',
#  'organism_quantity_type',
#  'sex',
#  'reproductiveCondition',
#  'behavior',
#  'establishmentMeans',
#  'occurrenceStatus',
#  'preparations',
#  'disposition',
#  'associatedMedia',
#  'associatedSequences',
#  'associatedTaxa',
#  'otherCatalogNumbers',
#  'occurrenceRemarks',
#  'previousIdentifications',
#  'eventID',
#  'fieldNumber',
#  'eventDate',
#  'eventTime',
#  'startDayOfYear',
#  'endDayOfYear',
#  'year',
#  'month',
#  'day',
#  'verbatimEventDate',
#  'habitat',
#  'samplingEffort',
#  'fieldNotes',
# ...

# %%
data['waterBody'].dropna(1)
# Out:
# C:\Users\salba\AppData\Local\Temp\ipykernel_34164\4033891371.py:1: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   data['waterBody'].dropna(1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 data['waterBody'].dropna(1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
# ...

# %%
cotorras = data3[data3['species'] == "Myiopsitta monachus"]
len(cotorras.index)
# Out:
# 241
